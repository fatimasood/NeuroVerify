# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {},
      "source": [
        "# Trustify: Fuzzy Logic-Based Hybrid Framework for Fake News Detection\n",
        "## Complete Reproduction of Paper Results\n",
        "\n",
        "**Paper**: A novel fuzzy logic-based hybrid framework for detecting fake news\n",
        "**Authors**: Rakesh Bharati, Jyoti Bharti, Vasudev Dehalwar\n",
        "**Datasets**: Twitter (~17k), BuzzFeed (~2.7k), PolitiFact (~11k)\n",
        "\n",
        "This notebook reproduces all results from the paper including:\n",
        "- LSTM-based text encoder (Section 3.4)\n",
        "- GNN-embedded Transformer for images (Section 3.2-3.3)\n",
        "- Fuzzy logic decision system with rules from Table 2 (Section 3.5)\n",
        "- Training on 80/10/10 splits (Section 4.3)\n",
        "- Comparison with SOTA models (Figures 10-12)"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 1: Mount Google Drive and setup\n",
        "from google.colab import drive\n",
        "drive.mount('/content/drive')\n",
        "\n",
        "# Create working directory\n",
        "!mkdir -p /content/trustify\n",
        "%cd /content/trustify"
      ],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 2: Install dependencies\n",
        "!pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118\n",
        "!pip install -q transformers numpy pandas scikit-learn matplotlib seaborn pillow\n",
        "!pip install -q opencv-python scipy networkx tqdm kagglehub plotly requests\n",
        "!pip install -q torch-geometric\n",
        "\n",
        "print(\"✓ All dependencies installed\")"
      ],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 3: Download all code files\n",
        "import os\n",
        "\n",
        "# Create directory structure\n",
        "for d in ['src/data', 'src/models', 'outputs/plots', 'outputs/models', 'data']:\n",
        "    os.makedirs(d, exist_ok=True)\n",
        "\n",
        "# Download the complete training script\n",
        "!wget -q https://raw.githubusercontent.com/trustify/fake-news-detection/main/train_complete.py -O train_complete.py\n",
        "\n",
        "# Or create files directly (paste the code from above)\n",
        "print(\"✓ Directory structure created\")"
      ],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 4: Create the complete training script\n",
        "%%writefile train_complete.py\n",
        "# [PASTE THE ENTIRE train_complete.py FROM ABOVE HERE]"
      ],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 5: Run the complete training\n",
        "!python train_complete.py"
      ],
      "execution_count": null
    },
    {
      "cell_type": "code",
      "metadata": {},
      "source": [
        "# Step 6: Display results\n",
        "import pandas as pd\n",
        "import matplotlib.pyplot as plt\n",
        "import IPython.display as display\n",
        "\n",
        "# Load results\n",
        "results = pd.read_csv('outputs/results_summary.csv', index_col=0)\n",
        "comparison = pd.read_csv('outputs/paper_comparison.csv', index_col=0)\n",
        "\n",
        "print(\"=\"*60)\n",
        "print(\"REPRODUCED RESULTS\")\n",
        "print(\"=\"*60)\n",
        "print(results)\n",
        "\n",
        "print(\"\\n\" + \"=\"*60)\n",
        "print(\"COMPARISON WITH PAPER\")\n",
        "print(\"=\"*60)\n",
        "print(comparison)\n",
        "\n",
        "# Display plots\n",
        "from IPython.display import Image\n",
        "for dataset in ['twitter', 'buzzfeed', 'politifact']:\n",
        "    print(f\"\\n{dataset.upper()} Results:\")\n",
        "    display.display(Image(f'outputs/plots/{dataset}_metrics.png'))"
      ],
      "execution_count": null
    }
  ]
}
